# %% [markdown]
# # Colab Setup for All Models

# %% [markdown]
# ### Run this notebook first to configure your Colab environment

# %% [markdown]
# ###### NOTE: Change the URL to the correct branch when you merge to main!

# %%
from google.colab import drive
drive.mount('/content/drive')

# Install requirements from your branch
# !pip install -r https://raw.githubusercontent.com/eteitelbaum/code-satp/imbalance-handling-strategies/requirements.txt

# Clone the full repository
# !git clone -b imbalance-handling-strategies https://github.com/eteitelbaum/code-satp.git

# Create Google Drive directories for results
import os
os.makedirs("/content/drive/MyDrive/colab/satp-data", exist_ok=True)
os.makedirs("/content/drive/MyDrive/colab/satp-results/actiontype", exist_ok=True)
os.makedirs("/content/drive/MyDrive/colab/satp-results/perpetrator", exist_ok=True)
os.makedirs("/content/drive/MyDrive/colab/satp-results/targettype", exist_ok=True)

# Verify GPU availability
import torch
if torch.cuda.is_available():
    print(f"✅ GPU Available: {torch.cuda.get_device_name(0)}")
else:
    print("⚠️ GPU not available, using CPU")

print("🎉 SATP Colab Environment Setup Complete!")
print("📁 Repository cloned to: /content/code-satp")
print()
print("🎯 Next Steps:")
print("1. Navigate to: /content/code-satp/models/classification-models/")
print("2. Open your desired notebook: actiontype.ipynb, perpetrator.ipynb, or targettype.ipynb")
print("3. Run the notebooks directly - they'll automatically use the cloned utils!")
